# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine
from pyspark.sql import SparkSession
# Database connection parameters
db_host = 'database-1.cxoaueie6ybk.us-east-2.rds.amazonaws.com'
db_port = 5432  # Default PostgreSQL port is 5432
db_name = 'postgres'
db_user = 'root'
db_password = 'irODJyh3LQpE0V3OcE3o'

# Create an engine to connect to the database
engine = create_engine(f'postgresql+psycopg2://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}')

# Establish a connection to the database
conn = psycopg2.connect(
    host=db_host,
    port=db_port,
    dbname=db_name,
    user=db_user,
    password=db_password
)
# SQL query to fetch data
query = 'SELECT * FROM darwin'

# Load data into a DataFrame
df = pd.read_sql(query, con = conn)

df
# Out:
# /tmp/ipykernel_166/1125145934.py:27: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, con = conn)
#                route_id unique_id service_start_date update_origin  \
# 0       202407038081744    P81744         2024-07-03            TD
# 1       202407038097422    P97422         2024-07-03            TD
# 2       202407038097422    P97422         2024-07-03            TD
# 3       202407037143658    G43658         2024-07-03            TD
# 4       202407037143658    G43658         2024-07-03            TD
# ...                 ...       ...                ...           ...
# 258944  202407088098423    P98423         2024-07-08            TD
# 258945  202407086748577    C48577         2024-07-08            TD
# 258946  202407087668728    L68728         2024-07-08           CIS
# 258947  202407088098055    P98055         2024-07-08            TD
# 258948  202407086735886    C35886         2024-07-08            TD
#
#        train_platform working_time_pass working_time_arrival  \
# 0                CCRT              None             23:17:00
# 1             ALBNYPK              None             23:14:00
# 2              BEXLEY              None             23:16:30
# 3             SHAL341              None             23:29:00
# 4              SHALFD              None             23:34:00
# ...               ...               ...                  ...
# 258944        LEWISHM              None             14:30:30
# 258945           STKP              None             14:11:30
# 258946        CHLMSFD              None             14:27:00
# 258947        SNODLND              None             14:14:00
# 258948        JAMESST              None             14:14:00
#
#        working_time_departure planned_time_arrival planned_time_departure  \
# 0                    23:17:30             23:17:00               23:17:00
# 1                    23:14:30             23:14:00               23:14:00
# 2                    23:17:30             23:17:00               23:17:00
# 3                    23:32:00                 None                   None
# 4                    23:35:30                 None                   None
# ...                       ...                  ...                    ...
# 258944               14:32:00             14:31:00               14:32:00
# 258945               14:13:00             14:12:00               14:13:00
# 258946               14:28:00             14:27:00               14:28:00
# 258947               14:15:00             14:14:00               14:15:00
# 258948               14:14:30             14:14:00               14:14:00
#
#         ... platform train_length estimated_time  source actual_time  \
# 0       ...        2          NaN           None    None        None
# 1       ...        2          8.0           None    None        None
# 2       ...        2          8.0           None    None        None
# 3       ...     None          NaN           None    None        None
# 4       ...     None          NaN           None    None        None
# ...     ...      ...          ...            ...     ...         ...
# 258944  ...        3          4.0           None    None        None
# 258945  ...        2          NaN           None    None        None
# 258946  ...        2         12.0           None    None        None
# 258947  ...        2          3.0           None    None        None
# 258948  ...        1          NaN           None    None        None
#
#        actual_time_class is_delayed_arrival is_delayed_departure  \
# 0                   None              False                False
# 1                   None              False                False
# 2                   None              False                False
# 3                   None              False                False
# 4                   None              False                False
# ...                  ...                ...                  ...
# 258944              None              False                False
# 258945              None              False                False
# 258946              None              False                False
# 258947              None              False                False
# 258948              None              False                False
#
#         source_instance  estimated_time_minutes
# 0                  None                    None
# 1                  None                    None
# 2                  None                    None
# 3                  None                    None
# 4                  None                    None
# ...                 ...                     ...
# 258944             None                    None
# 258945             None                    None
# 258946             None                    None
# 258947             None                    None
# 258948             None                    None
#
# [258949 rows x 22 columns]

# %%
from pyspark.sql import SparkSession
# Initialize Spark session
spark = SparkSession.builder \
    .appName("Pandas to PySpark") \
    .getOrCreate()

#not working current as AttributeError: 'datetime.time' object has no attribute 'timetuple'
spark_df = spark.createDataFrame(df)
spark_df.printScheme()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 8
#       2 # Initialize Spark session
#       3 spark = SparkSession.builder \
#       4     .appName("Pandas to PySpark") \
#       5     .getOrCreate()
# ----> 8 spark_df = spark.createDataFrame(df)
#       9 spark_df.printScheme()
#
# File /usr/local/spark/python/pyspark/sql/session.py:1440, in SparkSession.createDataFrame(self, data, schema, samplingRatio, verifySchema)
#    1436     data = pd.DataFrame(data, columns=column_names)
#    1438 if has_pandas and isinstance(data, pd.DataFrame):
#    1439     # Create a DataFrame from pandas DataFrame.
# -> 1440     return super(SparkSession, self).createDataFrame(  # type: ignore[call-overload]
#    1441         data, schema, samplingRatio, verifySchema
#    1442     )
#    1443 return self._create_dataframe(
#    1444     data, schema, samplingRatio, verifySchema  # type: ignore[arg-type]
#    1445 )
#
# File /usr/local/spark/python/pyspark/sql/pandas/conversion.py:363, in SparkConversionMixin.createDataFrame(self, data, schema, samplingRatio, verifySchema)
#     361             raise
#     362 converted_data = self._convert_from_pandas(data, schema, timezone)
# --> 363 return self._create_dataframe(converted_data, schema, samplingRatio, verifySchema)
#
# File /usr/local/spark/python/pyspark/sql/session.py:1485, in SparkSession._create_dataframe(self, data, schema, samplingRatio, verifySchema)
#    1483     rdd, struct = self._createFromRDD(data.map(prepare), schema, samplingRatio)
#    1484 else:
# -> 1485     rdd, struct = self._createFromLocal(map(prepare, data), schema)
#    1486 assert self._jvm is not None
#    1487 jrdd = self._jvm.SerDeUtil.toJavaArray(rdd._to_java_object_rdd())
#
# File /usr/local/spark/python/pyspark/sql/session.py:1115, in SparkSession._createFromLocal(self, data, schema)
#    1106     raise PySparkTypeError(
#    1107         error_class="NOT_LIST_OR_NONE_OR_STRUCT",
#    1108         message_parameters={
#    (...)
#    1111         },
#    1112     )
#    1114 # convert python objects to sql data
# -> 1115 internal_data = [struct.toInternal(row) for row in tupled_data]
#    1116 return self._sc.parallelize(internal_data), struct
#
# File /usr/local/spark/python/pyspark/sql/session.py:1115, in <listcomp>(.0)
#    1106     raise PySparkTypeError(
#    1107         error_class="NOT_LIST_OR_NONE_OR_STRUCT",
#    1108         message_parameters={
#    (...)
#    1111         },
#    1112     )
#    1114 # convert python objects to sql data
# -> 1115 internal_data = [struct.toInternal(row) for row in tupled_data]
#    1116 return self._sc.parallelize(internal_data), struct
#
# File /usr/local/spark/python/pyspark/sql/types.py:1048, in StructType.toInternal(self, obj)
#    1043     return tuple(
#    1044         f.toInternal(obj.get(n)) if c else obj.get(n)
#    1045         for n, f, c in zip(self.names, self.fields, self._needConversion)
#    1046     )
#    1047 elif isinstance(obj, (tuple, list)):
# -> 1048     return tuple(
#    1049         f.toInternal(v) if c else v
#    1050         for f, v, c in zip(self.fields, obj, self._needConversion)
#    1051     )
#    1052 elif hasattr(obj, "__dict__"):
#    1053     d = obj.__dict__
#
# File /usr/local/spark/python/pyspark/sql/types.py:1049, in <genexpr>(.0)
#    1043     return tuple(
#    1044         f.toInternal(obj.get(n)) if c else obj.get(n)
#    1045         for n, f, c in zip(self.names, self.fields, self._needConversion)
#    1046     )
#    1047 elif isinstance(obj, (tuple, list)):
#    1048     return tuple(
# -> 1049         f.toInternal(v) if c else v
#    1050         for f, v, c in zip(self.fields, obj, self._needConversion)
#    1051     )
#    1052 elif hasattr(obj, "__dict__"):
#    1053     d = obj.__dict__
#
# File /usr/local/spark/python/pyspark/sql/types.py:717, in StructField.toInternal(self, obj)
#     716 def toInternal(self, obj: T) -> T:
# --> 717     return self.dataType.toInternal(obj)
#
# File /usr/local/spark/python/pyspark/sql/types.py:275, in TimestampType.toInternal(self, dt)
#     272 def toInternal(self, dt: datetime.datetime) -> int:
#     273     if dt is not None:
#     274         seconds = (
# --> 275             calendar.timegm(dt.utctimetuple()) if dt.tzinfo else time.mktime(dt.timetuple())
#     276         )
#     277         return int(seconds) * 1000000 + dt.microsecond
#
# AttributeError: 'datetime.time' object has no attribute 'timetuple'

# %%
#getting an overview of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255278 entries, 0 to 255277
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   route_id                255278 non-null  object
#  1   unique_id               255278 non-null  object
#  2   service_start_date      255278 non-null  object
#  3   update_origin           248641 non-null  object
#  4   train_platform          255278 non-null  object
#  5   working_time_pass       0 non-null       object
#  6   working_time_arrival    255278 non-null  object
#  7   working_time_departure  255278 non-null  object
#  8   planned_time_arrival    231285 non-null  object
#  9   planned_time_departure  230324 non-null  object
#  10  actual_arrival_time     213893 non-null  object
#  11  actual_departure_time   237596 non-null  object
#  12  platform                239741 non-null  object
#  13  train_length            88891 non-null   float64
#  14  estimated_time          0 non-null       object
#  15  source                  0 non-null       object
#  16  actual_time             0 non-null       object
#  17  actual_time_class       0 non-null       object
#  18  is_delayed_arrival      255278 non-null  bool
#  19  is_delayed_departure    255278 non-null  bool
#  20  source_instance         0 non-null       object
#  21  estimated_time_minutes  0 non-null       object
# dtypes: bool(2), float64(1), object(19)
# memory usage: 39.4+ MB

# %%
#dropping null columns and showing new dataframe overview
df = df.drop(['working_time_pass','estimated_time','source','actual_time','actual_time_class','source_instance','estimated_time_minutes'], axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255278 entries, 0 to 255277
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   route_id                255278 non-null  object
#  1   unique_id               255278 non-null  object
#  2   service_start_date      255278 non-null  object
#  3   update_origin           248641 non-null  object
#  4   train_platform          255278 non-null  object
#  5   working_time_arrival    255278 non-null  object
#  6   working_time_departure  255278 non-null  object
#  7   planned_time_arrival    231285 non-null  object
#  8   planned_time_departure  230324 non-null  object
#  9   actual_arrival_time     213893 non-null  object
#  10  actual_departure_time   237596 non-null  object
#  11  platform                239741 non-null  object
#  12  train_length            88891 non-null   float64
#  13  is_delayed_arrival      255278 non-null  bool
#  14  is_delayed_departure    255278 non-null  bool
# dtypes: bool(2), float64(1), object(12)
# memory usage: 25.8+ MB

# %%
#checking duplicates
df.duplicated().sum()
# Out:
# 9192

# %%
#dropping duplicates
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# 0

# %%
#taking in rail reference csv to extract information about the stations routes are interacting with
df2 = pd.read_csv("./Data/RailReferences.csv")
df2.head()
# Out:
#       AtcoCode TiplocCode CrsCode                      StationName  \
# 0  9100PENZNCE    PENZNCE     PNZ            Penzance Rail Station
# 1   9100STIVES     STIVES     SIV  St Ives (Cornwall) Rail Station
# 2  9100CARBISB    CARBISB     CBB          Carbis Bay Rail Station
# 3   9100STERTH     STERTH     SER             St Erth Rail Station
# 4  9100LELANTS    LELANTS     LTS     Lelant Saltings Rail Station
#
#    StationNameLang GridType  Easting  Northing     CreationDateTime  \
# 0              NaN        U   147588     30599  2003-11-04T00:00:00
# 1              NaN        U   151947     40127  2005-04-04T00:00:00
# 2              NaN        U   152930     38745  2003-11-04T00:00:00
# 3              NaN        U   154150     35730  2003-11-04T00:00:00
# 4              NaN        U   154430     36640  2003-11-04T00:00:00
#
#   ModificationDateTime  RevisionNumber Modification
# 0  2011-09-30T14:47:28               2          rev
# 1  2011-09-30T14:47:28               4          rev
# 2  2011-09-30T14:47:28               5          rev
# 3  2007-02-13T17:06:21               3          rev
# 4  2011-09-30T14:47:28               2          rev

# %%
#dropping information about the rail stations that we do not need
df2 = df2.drop(["StationNameLang","GridType","AtcoCode","Modification","CreationDateTime","ModificationDateTime","RevisionNumber","CrsCode"],axis=1)
df2
# Out:
#      TiplocCode                      StationName  Easting  Northing
# 0       PENZNCE            Penzance Rail Station   147588     30599
# 1        STIVES  St Ives (Cornwall) Rail Station   151947     40127
# 2       CARBISB          Carbis Bay Rail Station   152930     38745
# 3        STERTH             St Erth Rail Station   154150     35730
# 4       LELANTS     Lelant Saltings Rail Station   154430     36640
# ...         ...                              ...      ...       ...
# 2623    SMRLYTN         Somerleyton Rail Station   647930    296530
# 2624    OULTNBS  Oulton Broad South Rail Station   651920    292205
# 2625     YARMTH      Great Yarmouth Rail Station   652000    308100
# 2626    OULTNBN  Oulton Broad North Rail Station   652420    293140
# 2627    LOWSTFT           Lowestoft Rail Station   654747    292890
#
# [2628 rows x 4 columns]

# %%
#merging together the information about the train platform for each route
merged_df = pd.merge(df, df2, left_on='train_platform', right_on='TiplocCode', how='left')

# %%
#showing the new dataframe with station information
merged_df.head()
# Out:
#           route_id unique_id service_start_date update_origin train_platform  \
# 0  202407038081744    P81744         2024-07-03            TD           CCRT
# 1  202407038097422    P97422         2024-07-03            TD        ALBNYPK
# 2  202407038097422    P97422         2024-07-03            TD         BEXLEY
# 3  202407037143658    G43658         2024-07-03            TD        SHAL341
# 4  202407037143658    G43658         2024-07-03            TD         SHALFD
#
#   working_time_arrival working_time_departure planned_time_arrival  \
# 0             23:17:00               23:17:30             23:17:00
# 1             23:14:00               23:14:30             23:14:00
# 2             23:16:30               23:17:30             23:17:00
# 3             23:29:00               23:32:00                 None
# 4             23:34:00               23:35:30                 None
#
#   planned_time_departure actual_arrival_time actual_departure_time platform  \
# 0               23:17:00                None              23:17:00        2
# 1               23:14:00                None                  None        2
# 2               23:17:00            23:18:00              23:19:00        2
# 3                   None            23:30:00              23:31:00     None
# 4                   None            23:33:00              23:34:00     None
#
#    train_length  is_delayed_arrival  is_delayed_departure TiplocCode  \
# 0           NaN               False                 False       CCRT
# 1           8.0               False                 False    ALBNYPK
# 2           8.0               False                 False     BEXLEY
# 3           NaN               False                 False        NaN
# 4           NaN               False                 False     SHALFD
#
#                       StationName   Easting  Northing
# 0           Cathcart Rail Station  258460.0  660580.0
# 1        Albany Park Rail Station  547855.0  172860.0
# 2             Bexley Rail Station  549380.0  173435.0
# 3                             NaN       NaN       NaN
# 4  Shalford (Surrey) Rail Station  500200.0  147100.0

# %%
#setting the working df to the merged df and dropping TiplocCode as it is no longer needed
df = merged_df.drop(["TiplocCode"],axis = 1)

# %%
df.head()
# Out:
#           route_id unique_id service_start_date update_origin train_platform  \
# 0  202407038081744    P81744         2024-07-03            TD           CCRT
# 1  202407038097422    P97422         2024-07-03            TD        ALBNYPK
# 2  202407038097422    P97422         2024-07-03            TD         BEXLEY
# 3  202407037143658    G43658         2024-07-03            TD        SHAL341
# 4  202407037143658    G43658         2024-07-03            TD         SHALFD
#
#   working_time_pass working_time_arrival working_time_departure  \
# 0              None             23:17:00               23:17:30
# 1              None             23:14:00               23:14:30
# 2              None             23:16:30               23:17:30
# 3              None             23:29:00               23:32:00
# 4              None             23:34:00               23:35:30
#
#   planned_time_arrival planned_time_departure  ... platform train_length  \
# 0             23:17:00               23:17:00  ...        2          NaN
# 1             23:14:00               23:14:00  ...        2          8.0
# 2             23:17:00               23:17:00  ...        2          8.0
# 3                 None                   None  ...     None          NaN
# 4                 None                   None  ...     None          NaN
#
#   estimated_time  source actual_time actual_time_class is_delayed_arrival  \
# 0           None    None        None              None              False
# 1           None    None        None              None              False
# 2           None    None        None              None              False
# 3           None    None        None              None              False
# 4           None    None        None              None              False
#
#   is_delayed_departure  source_instance  estimated_time_minutes
# 0                False             None                    None
# 1                False             None                    None
# 2                False             None                    None
# 3                False             None                    None
# 4                False             None                    None
#
# [5 rows x 22 columns]

# %%
#looking at null values accross the dataframe
df.isna().sum()
# Out:
# route_id                       0
# unique_id                      0
# service_start_date             0
# update_origin               6900
# train_platform                 0
# working_time_pass         258949
# working_time_arrival           0
# working_time_departure         0
# planned_time_arrival       24114
# planned_time_departure     25079
# actual_arrival_time        42059
# actual_departure_time      18025
# platform                   15634
# train_length              168420
# estimated_time            258949
# source                    258949
# actual_time               258949
# actual_time_class         258949
# is_delayed_arrival             0
# is_delayed_departure           0
# source_instance           258949
# estimated_time_minutes    258949
# dtype: int64

# %%
#dropping the nulls in Easting and Northing before converting them to Latitude and Longitude
df = df.dropna(subset=['Easting', 'Northing'])

# %%
#installing a necessary package to convert northing and easting to latitude and longitude
# !pip install bng_latlon
# Out:
# Requirement already satisfied: bng_latlon in /opt/conda/lib/python3.11/site-packages (1.1)

# %%
# Function to convert to Latitude and Longitude
# !pip install bng_latlon
from bng_latlon import OSGB36toWGS84
def latlong(df):
    lat_long = []
    for i in range(len(df)):
        lat_long.append( OSGB36toWGS84(df[i][0],df[i][1]) )
    return lat_long
df['Easting'] = df['Easting'].astype('int64')
df['Northing'] = df['Northing'].astype('int64')
df1 = df [['Easting','Northing']]
values = (df1.values)
lat_long = latlong(values)
#Writing to dataframe
lat = []
long = []
for i in range(len(lat_long)):
    lat.append(lat_long[i][0])
    long.append(lat_long[i][1])
    
df['Latitude'] = lat
df['Longitude'] = long
# Out:
# /tmp/ipykernel_166/193497253.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Easting'] = df['Easting'].astype('int64')
# /tmp/ipykernel_166/193497253.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Northing'] = df['Northing'].astype('int64')
# /tmp/ipykernel_166/193497253.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Latitude'] = lat
# /tmp/ipykernel_166/193497253.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Longitude'] = long

# %%
#looking at the data after adding latitude and longitude columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 227020 entries, 0 to 246085
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   route_id                227020 non-null  object
#  1   unique_id               227020 non-null  object
#  2   service_start_date      227020 non-null  datetime64[ns]
#  3   update_origin           221338 non-null  object
#  4   train_platform          227020 non-null  object
#  5   working_time_arrival    227020 non-null  object
#  6   working_time_departure  227020 non-null  object
#  7   planned_time_arrival    213261 non-null  object
#  8   planned_time_departure  212448 non-null  object
#  9   actual_arrival_time     187772 non-null  object
#  10  actual_departure_time   210249 non-null  object
#  11  platform                222583 non-null  object
#  12  train_length            82835 non-null   float64
#  13  is_delayed_arrival      227020 non-null  bool
#  14  is_delayed_departure    227020 non-null  bool
#  15  StationName             227020 non-null  object
#  16  Easting                 227020 non-null  int64
#  17  Northing                227020 non-null  int64
#  18  Latitude                227020 non-null  float64
#  19  Longitude               227020 non-null  float64
# dtypes: bool(2), datetime64[ns](1), float64(3), int64(2), object(12)
# memory usage: 33.3+ MB

# %%
#creating a new dataframe dropping all null values from the data
na_df = df.dropna()

# %%
#getting an overview of the amount of rows dropped and if we should continue with the null dropped dataset
na_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 166748 entries, 2 to 246085
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   route_id                166748 non-null  object
#  1   unique_id               166748 non-null  object
#  2   service_start_date      166748 non-null  datetime64[ns]
#  3   update_origin           166748 non-null  object
#  4   train_platform          166748 non-null  object
#  5   working_time_arrival    166748 non-null  object
#  6   working_time_departure  166748 non-null  object
#  7   planned_time_arrival    166748 non-null  object
#  8   planned_time_departure  166748 non-null  object
#  9   actual_arrival_time     166748 non-null  object
#  10  actual_departure_time   166748 non-null  object
#  11  platform                166748 non-null  object
#  12  is_delayed_arrival      166748 non-null  bool
#  13  is_delayed_departure    166748 non-null  bool
#  14  StationName             166748 non-null  object
#  15  Easting                 166748 non-null  int64
#  16  Northing                166748 non-null  int64
#  17  Latitude                166748 non-null  float64
#  18  Longitude               166748 non-null  float64
# dtypes: bool(2), datetime64[ns](1), float64(2), int64(2), object(12)
# memory usage: 23.2+ MB

# %%
#after considering the data dropped we believe the amount of data still remaining is sufficent to run our EDA
df = na_df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 166748 entries, 2 to 246085
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   route_id                166748 non-null  object
#  1   unique_id               166748 non-null  object
#  2   service_start_date      166748 non-null  datetime64[ns]
#  3   update_origin           166748 non-null  object
#  4   train_platform          166748 non-null  object
#  5   working_time_arrival    166748 non-null  object
#  6   working_time_departure  166748 non-null  object
#  7   planned_time_arrival    166748 non-null  object
#  8   planned_time_departure  166748 non-null  object
#  9   actual_arrival_time     166748 non-null  object
#  10  actual_departure_time   166748 non-null  object
#  11  platform                166748 non-null  object
#  12  is_delayed_arrival      166748 non-null  bool
#  13  is_delayed_departure    166748 non-null  bool
#  14  StationName             166748 non-null  object
#  15  Easting                 166748 non-null  int64
#  16  Northing                166748 non-null  int64
#  17  Latitude                166748 non-null  float64
#  18  Longitude               166748 non-null  float64
# dtypes: bool(2), datetime64[ns](1), float64(2), int64(2), object(12)
# memory usage: 23.2+ MB

# %%
#converting the dataframe into a csv file to be exported into other programs like PowerBI
df.to_csv('./Data/cleanRailData.csv')

# %%
#importing plotting libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.describe()
# Out:
#              Easting       Northing       Latitude      Longitude
# count  166748.000000  166748.000000  166748.000000  166748.000000
# mean   463735.638358  256648.926476      52.195307      -1.101893
# std     99609.999302  154916.627906       1.393826       1.471711
# min    152930.000000   32085.000000      50.148339      -5.839078
# 25%    389260.000000  169998.000000      51.414186      -2.163013
# 50%    516300.000000  184725.000000      51.543409      -0.327538
# 75%    533575.000000  322840.000000      52.778953      -0.075667
# max    652420.000000  967920.000000      58.590176       1.715711

# %%
from datetime import time
#changing the columns with times to datetime objects
df['service_start_date'] = pd.to_datetime(df['service_start_date'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 166748 entries, 2 to 246085
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   route_id                166748 non-null  object
#  1   unique_id               166748 non-null  object
#  2   service_start_date      166748 non-null  datetime64[ns]
#  3   update_origin           166748 non-null  object
#  4   train_platform          166748 non-null  object
#  5   working_time_arrival    166748 non-null  object
#  6   working_time_departure  166748 non-null  object
#  7   planned_time_arrival    166748 non-null  object
#  8   planned_time_departure  166748 non-null  object
#  9   actual_arrival_time     166748 non-null  object
#  10  actual_departure_time   166748 non-null  object
#  11  platform                166748 non-null  object
#  12  is_delayed_arrival      166748 non-null  bool
#  13  is_delayed_departure    166748 non-null  bool
#  14  StationName             166748 non-null  object
#  15  Easting                 166748 non-null  int64
#  16  Northing                166748 non-null  int64
#  17  Latitude                166748 non-null  float64
#  18  Longitude               166748 non-null  float64
# dtypes: bool(2), datetime64[ns](1), float64(2), int64(2), object(12)
# memory usage: 23.2+ MB

# %%
df.dtypes
# Out:
# route_id                          object
# unique_id                         object
# service_start_date        datetime64[ns]
# update_origin                     object
# train_platform                    object
# working_time_arrival              object
# working_time_departure            object
# planned_time_arrival              object
# planned_time_departure            object
# actual_arrival_time               object
# actual_departure_time             object
# platform                          object
# is_delayed_arrival                  bool
# is_delayed_departure                bool
# StationName                       object
# Easting                            int64
# Northing                           int64
# Latitude                         float64
# Longitude                        float64
# dtype: object

# %%
# Out:
#            route_id unique_id service_start_date update_origin train_platform  \
# 2   202407038097422    P97422         2024-07-03            TD         BEXLEY
# 12  202407037144273    G44273         2024-07-03            TD        GUILDFD
# 14  202407038080693    P80693         2024-07-03         Trust        PLKLHDW
# 15  202407038080693    P80693         2024-07-03         Trust        MAXWLPK
# 16  202407038080693    P80693         2024-07-03         Trust        SHWLNDS
#
#    working_time_arrival working_time_departure planned_time_arrival  \
# 2              23:16:30               23:17:30             23:17:00
# 12             23:19:00               23:20:30             23:19:00
# 14             23:17:30               23:18:00             23:18:00
# 15             23:19:30               23:20:00             23:20:00
# 16             23:21:30               23:22:00             23:22:00
#
#    planned_time_departure actual_arrival_time actual_departure_time platform  \
# 2                23:17:00            23:18:00              23:19:00        2
# 12               23:20:00            23:20:00              23:21:00        4
# 14               23:18:00            23:18:00              23:18:00        2
# 15               23:20:00            23:20:00              23:20:00        2
# 16               23:22:00            23:22:00              23:22:00        2
#
#     is_delayed_arrival  is_delayed_departure                      StationName  \
# 2                False                 False              Bexley Rail Station
# 12               False                 False           Guildford Rail Station
# 14               False                 False  Pollokshields West Rail Station
# 15               False                 False        Maxwell Park Rail Station
# 16               False                 False           Shawlands Rail Station
#
#     Easting  Northing   Latitude  Longitude
# 2    549380    173435  51.440218   0.147903
# 12   499200    149600  51.236968  -0.580425
# 14   257580    662840  55.837698  -4.275753
# 15   256770    662870  55.837728  -4.288692
# 16   256510    661930  55.829211  -4.292343

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52556 entries, 2 to 78315
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   route_id                52556 non-null  object
#  1   unique_id               52556 non-null  object
#  2   service_start_date      52556 non-null  datetime64[ns]
#  3   update_origin           52556 non-null  object
#  4   train_platform          52556 non-null  object
#  5   working_time_arrival    52556 non-null  object
#  6   working_time_departure  52556 non-null  object
#  7   planned_time_arrival    52556 non-null  object
#  8   planned_time_departure  52556 non-null  object
#  9   actual_arrival_time     52556 non-null  object
#  10  actual_departure_time   52556 non-null  object
#  11  platform                52556 non-null  object
#  12  is_delayed_arrival      52556 non-null  bool
#  13  is_delayed_departure    52556 non-null  bool
#  14  StationName             52556 non-null  object
#  15  Easting                 52556 non-null  int64
#  16  Northing                52556 non-null  int64
#  17  Latitude                52556 non-null  float64
#  18  Longitude               52556 non-null  float64
# dtypes: bool(2), datetime64[ns](1), float64(2), int64(2), object(12)
# memory usage: 7.3+ MB

# %%
from datetime import time, timedelta
df['arrival_vs_planned_time'] = df.apply(lambda row: timedelta(hours=row['actual_arrival_time'].hour - row['planned_time_arrival'].hour,
                                                       minutes=row['actual_arrival_time'].minute - row['planned_time_arrival'].minute,
                                                       seconds=row['actual_arrival_time'].second - row['planned_time_arrival'].second), axis=1)


df['arrival_vs_planned_time']
# Out:
# 2       0 days 00:01:00
# 12      0 days 00:01:00
# 14      0 days 00:00:00
# 15      0 days 00:00:00
# 16      0 days 00:00:00
#               ...
# 78311   0 days 00:12:00
# 78312   0 days 00:12:00
# 78313   0 days 00:02:00
# 78314   0 days 00:01:00
# 78315   0 days 00:51:00
# Name: arrival_vs_planned_time, Length: 52556, dtype: timedelta64[ns]

# %%
avg_time_difference = df.groupby('StationName')['arrival_vs_planned_time'].apply(lambda x: x.mean())

avg_time_difference
# Out:
# StationName
# Abbey Wood (London) Rail Station   0 days 00:02:07.826086956
# Aber Rail Station                            0 days 00:03:06
# Abercynon Rail Station             0 days 00:01:43.636363636
# Aberdeen Rail Station                        0 days 00:00:00
# Aberdour Rail Station              0 days 00:02:50.769230769
#                                               ...
# Yoker Rail Station                           0 days 00:01:00
# York Rail Station                  0 days 00:13:23.362831858
# Yorton Rail Station                        -1 days +18:09:45
# Ystrad Mynach Rail Station            0 days 00:03:55.200000
# Ystrad Rhondda Rail Station        0 days 00:00:50.769230769
# Name: arrival_vs_planned_time, Length: 2247, dtype: timedelta64[ns]
